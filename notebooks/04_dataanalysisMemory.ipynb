# %%
import sys
import os
project_root = '/work'

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import re
from scripts.utils.utils import normalize_text

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
dataset=pd.read_csv("/work/data/processed/03_extract_gpu_features.csv")
df=dataset.copy()
df.dropna(subset=["cpu"], inplace=True)

# %%
df["ram"].unique()
# Out:
# array(['16 GB', '4 GB', '8 GB', nan, '24 GB', '32 GB', '12 GB', '64 GB',
#        '40 GB', '6 GB', '48 GB', '96 GB', '80 GB', '20 GB', '36 GB',
#        '128 GB', '18 GB'], dtype=object)

# %%
ram_mapping = {
    '4 GB': 1,
    '6 GB': 2,
    '8 GB': 3,
    '12 GB': 4,
    '16 GB': 5,
    '18 GB': 6,
    '20 GB': 7,
    '24 GB': 8,
    '32 GB': 9,
    '36 GB': 10,
    '40 GB': 11,
    '48 GB': 12,
    '64 GB': 13,
    '80 GB': 14,
    '96 GB': 15,
    '128 GB': 16,
}

df['ram_priority'] = df['ram'].map(ram_mapping)

# %%
df["storage"].unique()
# Out:
# array(['512 GB', '128 GB', nan, '1 TB', '256 GB', '2 TB', '4 TB', '8 TB',
#        '6 TB', '500 GB', '120 GB', '480 GB', '250 GB'], dtype=object)

# %%
storage_mapping = {
    '120 GB': 1,
    '128 GB': 2,
    '250 GB': 3,
    '256 GB': 4,
    '480 GB': 5,
    '500 GB': 6,
    '512 GB': 7,
    '1 TB': 8,
    '2 TB': 9,
    '4 TB': 10,
    '6 TB': 11,
    '8 TB': 12,
}
df['storage_priority'] = df['storage'].map(storage_mapping)

# %%
df.to_csv("/work/data/processed/04_extract_memory_features.csv", index=False)
